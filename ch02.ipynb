# %%
# %run -i ch02.py

# %%
df.head(n=10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
# 5    -122.25     37.85                52.0        919.0           213.0
# 6    -122.25     37.84                52.0       2535.0           489.0
# 7    -122.25     37.84                52.0       3104.0           687.0
# 8    -122.26     37.84                42.0       2555.0           665.0
# 9    -122.25     37.84                52.0       3549.0           707.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
# 5       413.0       193.0         4.0368            269700.0        NEAR BAY
# 6      1094.0       514.0         3.6591            299200.0        NEAR BAY
# 7      1157.0       647.0         3.1200            241400.0        NEAR BAY
# 8      1206.0       595.0         2.0804            226700.0        NEAR BAY
# 9      1551.0       714.0         3.6912            261100.0        NEAR BAY

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
# longitude             20640 non-null float64
# latitude              20640 non-null float64
# housing_median_age    20640 non-null float64
# total_rooms           20640 non-null float64
# total_bedrooms        20433 non-null float64
# population            20640 non-null float64
# households            20640 non-null float64
# median_income         20640 non-null float64
# median_house_value    20640 non-null float64
# ocean_proximity       20640 non-null object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
df[KEY_OCEAN_PROXIMITY].value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
df.hist(bins=50, figsize=(20, 15))
plt.show()

# %%
df.plot(kind='scatter', x=KEY_LONGITUDE, y=KEY_LATITUDE, alpha=0.1)

# %%
df.plot(
    kind='scatter', x=KEY_LONGITUDE, y=KEY_LATITUDE,
    s=df[KEY_POPULATION]/100, label=KEY_POPULATION,
    c=KEY_MEDIAN_VALUE, cmap=plt.get_cmap('jet'),
    alpha=0.4, figsize=(10, 7)
)

plt.legend()

# %%
prep.corr()
# Out:
#                     NEAR BAY  <1H OCEAN    INLAND  NEAR OCEAN    ISLAND  \
# NEAR BAY            1.000000  -0.314813 -0.240887   -0.135818 -0.005499
# <1H OCEAN          -0.314813   1.000000 -0.607669   -0.342620 -0.013872
# INLAND             -0.240887  -0.607669  1.000000   -0.262163 -0.010614
# NEAR OCEAN         -0.135818  -0.342620 -0.262163    1.000000 -0.005985
# ISLAND             -0.005499  -0.013872 -0.010614   -0.005985  1.000000
# longitude          -0.474489   0.321121 -0.055575    0.045509  0.009446
# latitude            0.358771  -0.446969  0.351166   -0.160818 -0.016572
# housing_median_age  0.255172   0.045300 -0.236645    0.021622  0.017020
# total_rooms        -0.023022  -0.003031  0.025624   -0.009175 -0.007572
# total_bedrooms     -0.019667   0.017966 -0.006158    0.000557 -0.004322
# population         -0.060880   0.074613 -0.020732   -0.024264 -0.010412
# households         -0.010093   0.042435 -0.039402    0.001714 -0.009077
# median_income       0.056197   0.168876 -0.237496    0.027344 -0.009228
# median_house_value  0.160284   0.256617 -0.484859    0.141862  0.023416
# rooms/hh           -0.023304  -0.115977  0.167051   -0.038525  0.004680
# bedrooms/room       0.001477   0.076502 -0.114821    0.043962  0.016546
#
#                     longitude  latitude  housing_median_age  total_rooms  \
# NEAR BAY            -0.474489  0.358771            0.255172    -0.023022
# <1H OCEAN            0.321121 -0.446969            0.045300    -0.003031
# INLAND              -0.055575  0.351166           -0.236645     0.025624
# NEAR OCEAN           0.045509 -0.160818            0.021622    -0.009175
# ISLAND               0.009446 -0.016572            0.017020    -0.007572
# longitude            1.000000 -0.924664           -0.108197     0.044568
# latitude            -0.924664  1.000000            0.011173    -0.036100
# housing_median_age  -0.108197  0.011173            1.000000    -0.361262
# total_rooms          0.044568 -0.036100           -0.361262     1.000000
# total_bedrooms       0.069120 -0.066484           -0.319026     0.927058
# population           0.099773 -0.108785           -0.296244     0.857126
# households           0.055310 -0.071035           -0.302916     0.918484
# median_income       -0.015176 -0.079809           -0.119034     0.198050
# median_house_value  -0.045967 -0.144160            0.105623     0.134153
# rooms/hh            -0.072099  0.130245           -0.229996     0.237299
# bedrooms/room        0.092010 -0.113218            0.133606    -0.182086
#
#                     total_bedrooms  population  households  median_income  \
# NEAR BAY                 -0.019667   -0.060880   -0.010093       0.056197
# <1H OCEAN                 0.017966    0.074613    0.042435       0.168876
# INLAND                   -0.006158   -0.020732   -0.039402      -0.237496
# NEAR OCEAN                0.000557   -0.024264    0.001714       0.027344
# ISLAND                   -0.004322   -0.010412   -0.009077      -0.009228
# longitude                 0.069120    0.099773    0.055310      -0.015176
# latitude                 -0.066484   -0.108785   -0.071035      -0.079809
# housing_median_age       -0.319026   -0.296244   -0.302916      -0.119034
# total_rooms               0.927058    0.857126    0.918484       0.198050
# total_bedrooms            1.000000    0.873535    0.974366      -0.007617
# population                0.873535    1.000000    0.907222       0.004834
# households                0.974366    0.907222    1.000000       0.013033
# median_income            -0.007617    0.004834    0.013033       1.000000
# median_house_value        0.049457   -0.024650    0.065843       0.688075
# rooms/hh                 -0.021767   -0.048725   -0.067324       0.650073
# bedrooms/room             0.078994    0.039387    0.068641      -0.615235
#
#                     median_house_value  rooms/hh  bedrooms/room
# NEAR BAY                      0.160284 -0.023304       0.001477
# <1H OCEAN                     0.256617 -0.115977       0.076502
# INLAND                       -0.484859  0.167051      -0.114821
# NEAR OCEAN                    0.141862 -0.038525       0.043962
# ISLAND                        0.023416  0.004680       0.016546
# longitude                    -0.045967 -0.072099       0.092010
# latitude                     -0.144160  0.130245      -0.113218
# housing_median_age            0.105623 -0.229996       0.133606
# total_rooms                   0.134153  0.237299      -0.182086
# total_bedrooms                0.049457 -0.021767       0.078994
# population                   -0.024650 -0.048725       0.039387
# households                    0.065843 -0.067324       0.068641
# median_income                 0.688075  0.650073      -0.615235
# median_house_value            1.000000  0.311075      -0.263986
# rooms/hh                      0.311075  1.000000      -0.800038
# bedrooms/room                -0.263986 -0.800038       1.000000

# %%
prep.corr()[KEY_MEDIAN_VALUE].sort_values(ascending=False)
# Out:
# median_house_value    1.000000
# median_income         0.688075
# rooms/hh              0.311075
# <1H OCEAN             0.256617
# NEAR BAY              0.160284
# NEAR OCEAN            0.141862
# total_rooms           0.134153
# housing_median_age    0.105623
# households            0.065843
# total_bedrooms        0.049457
# ISLAND                0.023416
# population           -0.024650
# longitude            -0.045967
# latitude             -0.144160
# bedrooms/room        -0.263986
# INLAND               -0.484859
# Name: median_house_value, dtype: float64

# %%
from pandas.plotting import scatter_matrix

attributes = [KEY_MEDIAN_VALUE, KEY_MEDIAN_INCOME, KEY_TOTAL_ROOMS, KEY_MEDIAN_AGE]
scatter_matrix(prep[attributes], alpha=0.1, figsize=(12, 8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x129fd87b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x124b6fb70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x124e67c18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1241a1cc0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1253d1dd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1287ce390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x127927ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x129171748>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x129171320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x124e6dcf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1295c9b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d450160>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12b24b6d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12b9fd940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1251a4128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12ae9c978>]],
#       dtype=object)

# %%
prep.plot(kind='scatter', x=KEY_MEDIAN_INCOME, y=KEY_MEDIAN_VALUE, alpha=0.1)

# %%
prep.plot(kind='scatter', x=KEY_ROOMS_PER_HOUSEHOLD, y=KEY_MEDIAN_VALUE, alpha=0.1)

# %%
prep.plot(kind='scatter', x=KEY_BEDROOMS_PER_ROOM, y=KEY_MEDIAN_VALUE, alpha=0.1)

# %%
train.describe()
# Out:
#            NEAR BAY     <1H OCEAN        INLAND    NEAR OCEAN        ISLAND  \
# count  16512.000000  16512.000000  16512.000000  16512.000000  16512.000000
# mean       0.111858      0.440649      0.318738      0.128634      0.000121
# std        0.315201      0.496480      0.466001      0.334804      0.011005
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      1.000000      1.000000      0.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#           longitude      latitude  housing_median_age   total_rooms  \
# count  16512.000000  16512.000000        16512.000000  16512.000000
# mean    -119.575834     35.639577           28.653101   2622.728319
# std        2.001860      2.138058           12.574726   2138.458419
# min     -124.350000     32.540000            1.000000      6.000000
# 25%     -121.800000     33.940000           18.000000   1443.000000
# 50%     -118.510000     34.260000           29.000000   2119.500000
# 75%     -118.010000     37.720000           37.000000   3141.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    16512.000000  16512.000000  16512.000000   16512.000000
# mean       534.017260   1419.790819    497.060380       3.875589
# std        410.834962   1115.686241    375.720845       1.904950
# min          2.000000      3.000000      2.000000       0.499900
# 25%        296.000000    784.000000    279.000000       2.566775
# 50%        435.000000   1164.000000    408.000000       3.540900
# 75%        641.000000   1719.250000    602.000000       4.744475
# max       6210.000000  35682.000000   5358.000000      15.000100
#
#            rooms/hh  bedrooms/room
# count  16512.000000   16512.000000
# mean       5.292983       0.213797
# std        1.218208       0.055734
# min        2.000000       0.100000
# 25%        4.442040       0.175576
# 50%        5.232284       0.203589
# 75%        6.056361       0.241258
# max        8.000000       0.400000
