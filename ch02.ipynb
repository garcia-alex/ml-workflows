# %%
# %run -i ch02.py

# %%
df.head(n=10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
# 5    -122.25     37.85                52.0        919.0           213.0
# 6    -122.25     37.84                52.0       2535.0           489.0
# 7    -122.25     37.84                52.0       3104.0           687.0
# 8    -122.26     37.84                42.0       2555.0           665.0
# 9    -122.25     37.84                52.0       3549.0           707.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# ...

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
# longitude             20640 non-null float64
# latitude              20640 non-null float64
# housing_median_age    20640 non-null float64
# total_rooms           20640 non-null float64
# total_bedrooms        20433 non-null float64
# population            20640 non-null float64
# households            20640 non-null float64
# median_income         20640 non-null float64
# median_house_value    20640 non-null float64
# ocean_proximity       20640 non-null object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
df[KEY_OCEAN_PROXIMITY].value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
df.hist(bins=50, figsize=(20, 15))
plt.show()

# %%
df.plot(kind='scatter', x=KEY_LONGITUDE, y=KEY_LATITUDE, alpha=0.1)

# %%
df.plot(
    kind='scatter', x=KEY_LONGITUDE, y=KEY_LATITUDE,
    s=df[KEY_POPULATION]/100, label=KEY_POPULATION,
    c=KEY_MEDIAN_VALUE, cmap=plt.get_cmap('jet'),
    alpha=0.4, figsize=(10, 7)
)

plt.legend()

# %%
prep.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924478           -0.105848     0.048871
# latitude            -0.924478  1.000000            0.005766    -0.039184
# housing_median_age  -0.105848  0.005766            1.000000    -0.364509
# total_rooms          0.048871 -0.039184           -0.364509     1.000000
# total_bedrooms       0.076248 -0.072083           -0.323781     0.926329
# population           0.108030 -0.115222           -0.298710     0.855109
# households           0.063070 -0.077647           -0.306428     0.918392
# median_income       -0.019583 -0.075205           -0.111360     0.200087
# median_house_value  -0.047432 -0.142724            0.114110     0.135097
# rooms/hh            -0.076720  0.134528           -0.228582     0.238550
# bedrooms/room        0.098849 -0.118507            0.143579    -0.205548
# <1H OCEAN            0.318168 -0.444096            0.048865     0.001073
# ...

# %%
prep.corr()[KEY_MEDIAN_VALUE].sort_values(ascending=False)
# Out:
# median_house_value    1.000000
# median_income         0.687160
# rooms/hh              0.312449
# <1H OCEAN             0.259521
# NEAR BAY              0.158733
# ISLAND                0.137378
# total_rooms           0.135097
# housing_median_age    0.114110
# households            0.064506
# total_bedrooms        0.047642
# INLAND                0.013709
# population           -0.026920
# longitude            -0.047432
# latitude             -0.142724
# bedrooms/room        -0.281471
# NEAR OCEAN           -0.482886
# Name: median_house_value, dtype: float64

# %%
from pandas.plotting import scatter_matrix

attributes = [KEY_MEDIAN_VALUE, KEY_MEDIAN_INCOME, KEY_TOTAL_ROOMS, KEY_MEDIAN_AGE]
scatter_matrix(prep[attributes], alpha=0.1, figsize=(12, 8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11a63f2b0>,
# ...
#       dtype=object)

# %%
prep.plot(kind='scatter', x=KEY_MEDIAN_INCOME, y=KEY_MEDIAN_VALUE, alpha=0.1)

# %%
prep.plot(kind='scatter', x=KEY_ROOMS_PER_HOUSEHOLD, y=KEY_MEDIAN_VALUE, alpha=0.1)

# %%
prep.plot(kind='scatter', x=KEY_BEDROOMS_PER_ROOM, y=KEY_MEDIAN_VALUE, alpha=0.1)

# %%
train.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  1.651200e+04  1.651200e+04        1.651200e+04  1.651200e+04
# mean  -4.353107e-15  2.284564e-15       -4.701235e-17  7.587062e-17
# std    1.000030e+00  1.000030e+00        1.000030e+00  1.000030e+00
# min   -2.384937e+00 -1.449760e+00       -2.199168e+00 -1.223689e+00
# 25%   -1.111083e+00 -7.949406e-01       -8.472092e-01 -5.516890e-01
# 50%    5.324379e-01 -6.452675e-01        2.758786e-02 -2.353301e-01
# 75%    7.822131e-01  9.730728e-01        6.638039e-01  2.423650e-01
# max    2.630550e+00  2.951564e+00        1.856709e+00  1.716114e+01
#
#        total_bedrooms    population    households  median_income  \
# count    1.651200e+04  1.651200e+04  1.651200e+04   1.651200e+04
# mean     1.360615e-16 -3.700743e-17  2.078979e-17  -2.102108e-16
# std      1.000030e+00  1.000030e+00  1.000030e+00   1.000030e+00
# min     -1.294944e+00 -1.269921e+00 -1.317668e+00  -1.772116e+00
# ...

# %%
prep.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0  -1.156043  0.771950            0.743331    -0.493234       -0.445438
# 1  -1.176025  0.659695           -1.165317    -0.908967       -1.036928
# 2   1.186849 -1.342183            0.186642    -0.313660       -0.153345
# 3  -0.017068  0.313576           -0.290520    -0.362762       -0.396756
# 4   0.492474 -0.659299           -0.926736     1.856193        2.412211
#
#    population  households  median_income  median_house_value  rooms/hh  \
# 0   -0.636211   -0.420698      -0.614937            0.688068 -0.548046
# 1   -0.998331   -1.022227       1.336459            1.154794  0.587656
# 2   -0.433639   -0.093318      -0.532046           -0.087217 -0.876621
# 3    0.036041   -0.383436      -1.045566           -1.388864 -0.049819
# 4    2.724154    2.570975      -0.441437            0.410625 -0.646193
#
#    bedrooms/room  <1H OCEAN  NEAR OCEAN  INLAND  NEAR BAY  ISLAND
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR

from evaluation import Evaluation

Evaluation(LinearRegression).run(train, labels)
Evaluation(DecisionTreeRegressor).run(train, labels)
Evaluation(RandomForestRegressor, n_estimators=10, random_state=42).run(train, labels)
Evaluation(SVR, kernel="linear")
# Out:
# 2019-02-02 23:53:44 ml           INFO     LinearRegression
# 2019-02-02 23:53:44 ml           INFO     ----------
# 2019-02-02 23:53:44 ml           INFO     ('mse:', '68116.10')
# 2019-02-02 23:53:44 ml           INFO     ==========
# 2019-02-02 23:53:44 ml           INFO     ('Scores:', '66005.66, 66664.44, 68021.11, 74051.58, 66877.67, 70441.28, 64374.22, 67829.53, 71325.61, 67518.31')
# 2019-02-02 23:53:44 ml           INFO     ('Mean:', '68310.94')
# 2019-02-02 23:53:44 ml           INFO     ('StdDev', '2703.75')
# 2019-02-02 23:53:44 ml           INFO     --------
#
#
# 2019-02-02 23:53:46 ml           INFO     DecisionTreeRegressor
# 2019-02-02 23:53:46 ml           INFO     ----------
# 2019-02-02 23:53:46 ml           INFO     ('mse:', '0.00')
# 2019-02-02 23:53:46 ml           INFO     ==========
# 2019-02-02 23:53:46 ml           INFO     ('Scores:', '71484.59, 65788.46, 72246.96, 71524.60, 70189.11, 73778.45, 69664.56, 70772.55, 69991.67, 69155.13')
# ...
